# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\BOARD INFINITY PROJECTS\Employee attribution\employee_attrition.csv")

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  50.0        No      Travel_Rarely     1126.0  Research & Development
# 1  36.0        No      Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes      Travel_Rarely      337.0                   Sales
# 3  50.0        No  Travel_Frequently     1246.0         Human Resources
# 4  52.0        No      Travel_Rarely      994.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 3               NaN          3        Medical              1             644
# 4               7.0          4  Life Sciences              1            1118
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1029, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                        893.0     37.930571     9.395978    18.0    31.00
# DailyRate                 1002.0    800.528942   408.109828   102.0   458.25
# DistanceFromHome           934.0      9.930407     8.421791     1.0     2.00
# Education                 1029.0      2.892128     1.053541     1.0     2.00
# EmployeeCount             1029.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1029.0   1024.367347   606.301635     1.0   496.00
# EnvironmentSatisfaction   1029.0      2.683188     1.096829     1.0     2.00
# HourlyRate                1029.0     66.680272    20.474094    30.0    48.00
# JobInvolvement            1029.0      2.713314     0.710146     1.0     2.00
# JobLevel                  1029.0      2.043732     1.118918     1.0     1.00
# JobSatisfaction           1029.0      2.712342     1.096889     1.0     2.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       893 non-null    float64
#  1   Attrition                 1029 non-null   object
#  2   BusinessTravel            1024 non-null   object
#  3   DailyRate                 1002 non-null   float64
#  4   Department                1029 non-null   object
#  5   DistanceFromHome          934 non-null    float64
#  6   Education                 1029 non-null   int64
#  7   EducationField            1029 non-null   object
#  8   EmployeeCount             1029 non-null   int64
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  HourlyRate                1029 non-null   int64
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Age                         136
# Attrition                     0
# BusinessTravel                5
# DailyRate                    27
# Department                    0
# DistanceFromHome             95
# Education                     0
# EducationField                0
# EmployeeCount                 0
# EmployeeNumber                0
# EnvironmentSatisfaction       0
# Gender                        0
# HourlyRate                    0
# JobInvolvement                0
# JobLevel                      0
# JobRole                       0
# JobSatisfaction               0
# MaritalStatus                 5
# MonthlyIncome                 0
# MonthlyRate                   0
# NumCompaniesWorked            0
# Over18                        0
# OverTime                      0
# PercentSalaryHike             0
# PerformanceRating             0
# RelationshipSatisfaction      0
# StandardHours                 0
# StockOptionLevel              0
# TotalWorkingYears             0
# ...

# %%
(df.isnull().sum()*100)/len(df)
# Out:
# Age                         13.216715
# Attrition                    0.000000
# BusinessTravel               0.485909
# DailyRate                    2.623907
# Department                   0.000000
# DistanceFromHome             9.232264
# Education                    0.000000
# EducationField               0.000000
# EmployeeCount                0.000000
# EmployeeNumber               0.000000
# EnvironmentSatisfaction      0.000000
# Gender                       0.000000
# HourlyRate                   0.000000
# JobInvolvement               0.000000
# JobLevel                     0.000000
# JobRole                      0.000000
# JobSatisfaction              0.000000
# MaritalStatus                0.485909
# MonthlyIncome                0.000000
# MonthlyRate                  0.000000
# NumCompaniesWorked           0.000000
# Over18                       0.000000
# OverTime                     0.000000
# PercentSalaryHike            0.000000
# PerformanceRating            0.000000
# ...

# %% [markdown]
# It is observed that above dataset contains 35 columns out of which 4 columns i.e. (Age, Buisness Travel, DailyRate, DistanceFromHome, Marital status) have missing values. 'Attrition' is the target variable ('yes' / 'No' ). Various Datatypes of the columns are object, integer, float.

# %% [markdown]
# **Missing value Treatment**

# %%
NewNumeric = df[['DistanceFromHome','PercentSalaryHike','TotalWorkingYears','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','TrainingTimesLastYear','NumCompaniesWorked']]
NewNumericMelt = NewNumeric.melt()
plt.figure(figsize=(15,10))
plt.title("Boxplots for Numeric Variables")
bp = sns.boxplot(x = 'variable', y='value', data = NewNumericMelt)
plt.xticks(fontsize = 10, rotation = 'vertical')
plt.show()

# %%
df.dropna(subset=['Age', 'BusinessTravel', 'DailyRate', 'DistanceFromHome', 'MaritalStatus'], inplace=True)
df.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0  50.0        No  Travel_Rarely     1126.0  Research & Development
# 1  36.0        No  Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes  Travel_Rarely      337.0                   Sales
# 4  52.0        No  Travel_Rarely      994.0  Research & Development
# 5  33.0       Yes  Travel_Rarely     1277.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 4               7.0          4  Life Sciences              1            1118
# 5              15.0          1        Medical              1             582
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
print('Total Number of Unique values in columns:')
for features in df:
    if(features != 'Attrition'):
        print(str(features)+ ': (Datatype:' +str(df[features].dtype) +') : ' +str(len(df[features].unique())))
# Out:
# Total Number of Unique values in columns:
# Age: (Datatype:float64) : 39
# BusinessTravel: (Datatype:object) : 3
# DailyRate: (Datatype:float64) : 589
# Department: (Datatype:object) : 3
# DistanceFromHome: (Datatype:float64) : 27
# Education: (Datatype:int64) : 5
# EducationField: (Datatype:object) : 6
# EmployeeCount: (Datatype:int64) : 1
# EmployeeNumber: (Datatype:int64) : 775
# EnvironmentSatisfaction: (Datatype:int64) : 4
# Gender: (Datatype:object) : 2
# HourlyRate: (Datatype:int64) : 71
# JobInvolvement: (Datatype:int64) : 4
# JobLevel: (Datatype:int64) : 5
# JobRole: (Datatype:object) : 9
# JobSatisfaction: (Datatype:int64) : 4
# MaritalStatus: (Datatype:object) : 3
# MonthlyIncome: (Datatype:int64) : 743
# MonthlyRate: (Datatype:int64) : 766
# NumCompaniesWorked: (Datatype:int64) : 10
# Over18: (Datatype:object) : 1
# OverTime: (Datatype:object) : 2
# PercentSalaryHike: (Datatype:int64) : 15
# PerformanceRating: (Datatype:int64) : 2
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
attrition_count = pd.DataFrame(df['Attrition'].value_counts())
attrition_count
# Out:
#      Attrition
# No         647
# Yes        128

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x1ccfce61e40>,
# ...
#  [Text(-1.1288944116220352, 0.6446684476601436, 'No'),
#   Text(0.9552183227593987, -0.5454887311986576, 'Yes')])

# %% [markdown]
# From the above pie chart we can see that some employees were attrited but maximum number of employees were not attrited.

# %%
plt.figure(figsize = (6,5))
Attrplots = sns.countplot(x = 'Attrition' , data = df)
plt.title('Countplot for Attrition column')
plt.show()

# %% [markdown]
# From the above observation also we can see the number of attritions. Employees who have resigned their rate is above 100 while the Employees who haven't resigned their rate is above 600.

# %%
attrition_dummies = pd.get_dummies(df['Attrition'])
attrition_dummies.head(10)
# Out:
#     No  Yes
# 0    1    0
# 1    1    0
# 2    0    1
# 4    1    0
# 5    0    1
# 6    1    0
# 7    1    0
# 9    1    0
# 11   1    0
# 12   1    0

# %% [markdown]
# Here I converted Attrition's ['No', 'Yes'] columns into [0,1] i.e. into integer format to perform the following operations.

# %%
df = pd.concat([df,attrition_dummies], axis = 1)
df.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0  50.0        No  Travel_Rarely     1126.0  Research & Development
# 1  36.0        No  Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes  Travel_Rarely      337.0                   Sales
# 4  52.0        No  Travel_Rarely      994.0  Research & Development
# 5  33.0       Yes  Travel_Rarely     1277.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 4               7.0          4  Life Sciences              1            1118
# 5              15.0          1        Medical              1             582
#
#    ...  StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
df.drop(['No'], axis = 1, inplace = True)
df.head()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 0  50.0        No  Travel_Rarely     1126.0  Research & Development
# 1  36.0        No  Travel_Rarely      216.0  Research & Development
# 2  21.0       Yes  Travel_Rarely      337.0                   Sales
# 4  52.0        No  Travel_Rarely      994.0  Research & Development
# 5  33.0       Yes  Travel_Rarely     1277.0  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0               1.0          2        Medical              1             997
# 1               6.0          2        Medical              1             178
# 2               7.0          1      Marketing              1            1780
# 4               7.0          4  Life Sciences              1            1118
# 5              15.0          1        Medical              1             582
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
#plotting barplot to check gender wise attrition.
plt.figure(figsize = (6,5))
sns.barplot(x = 'Gender', y = 'Yes' , data = df)
plt.title('Gender wise attrition')
plt.show()

# %% [markdown]
# From the above barplot we can see that males were attrited more than females.

# %%
#plotting barplot to check department wise attrition
plt.figure(figsize = (6,5))
sns.barplot(x = 'Department', y ='Yes', data = df)
plt.title('Department wise Attrition')
plt.show()

# %% [markdown]
# From the above barplot we can see the attrition rate is **maximum in 'Human Resources Department'** after that in'Sales Department' and least in 'Research & Development Department'.

# %%
# plotting barplot to check BuisnessTrvale wise attrition
plt.figure(figsize = (6,5))
sns.barplot(x = 'BusinessTravel', y = 'Yes', data = df)
plt.title('BusinessTravel wise Attrition')
plt.show()

# %% [markdown]
# Attrition rate is maximum for those employees who travels frequently and it is minimum for the employees who don't travel at all.

# %%
#checking attrition rate age wise
plt.figure(figsize = (10,8))
plt.xticks(fontsize= 8, rotation='vertical')
sns.barplot(x = 'Age', y = 'Yes', data = df)
plt.title('Age wise Attrition')
plt.show()

# %% [markdown]
# We can see that attrition rate is maximum in the age group from 18-22 and then in age group 57-58.

# %%
#checking attrition rate Total work years wise
plt.figure(figsize = (10,8))
plt.xticks(fontsize= 8, rotation='vertical')
sns.barplot(x = 'TotalWorkingYears', y = 'Yes', data = df)
plt.title('TotalWorkingYears wise Attrition')
plt.show()

# %% [markdown]
# Employees with 0-3 years of work experience shows maximum rate of attrition and on the other hand aslo Employees with 33-34 years of work experience shows maximum rate of attrition.

# %%
plt.figure(figsize = (6,5))
plt.xticks(fontsize= 8, rotation='vertical')
sns.barplot(x = 'EnvironmentSatisfaction', y = 'Yes', data = df)
plt.title('Work Environment wise Attrition')
plt.show()

# %% [markdown]
# Most employees seem to be satisfied with the working environment.

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),cbar=True,square=True,fmt='.1f',annot=True,cmap='Reds')
# Out:
# C:\Users\anjal\AppData\Local\Temp\ipykernel_18836\3908432138.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cbar=True,square=True,fmt='.1f',annot=True,cmap='Reds')
# <Axes: >

# %% [markdown]
# **As we can see, there isn't a very strong correlation of the target column with any of the numerical columns. But we can see other correlations such as;**
#
# 1) More senior employees have higher total working years (very obvious)
# 2) Higher performance ratings lead to salary hike percentage to increase
# 3) The more years an employee puts in, the more their monthly income increases
# 4) A lot of employees remain in their current role and also under the same manager as years pass by meaning they don't get promotion and this could be a major factor contributing to attrition
#
# **From here, we can deduct that the lack of promotions may be a crucial factor to attritions.**

# %%
sns.boxplot(df["YearsAtCompany"])
# Out:
# <Axes: >

# %% [markdown]
# Most employees remain in the company for 3-9 years with median being 5 years.

# %%
df
# Out:
#        Age Attrition BusinessTravel  DailyRate              Department  \
# 0     50.0        No  Travel_Rarely     1126.0  Research & Development
# 1     36.0        No  Travel_Rarely      216.0  Research & Development
# 2     21.0       Yes  Travel_Rarely      337.0                   Sales
# 4     52.0        No  Travel_Rarely      994.0  Research & Development
# 5     33.0       Yes  Travel_Rarely     1277.0  Research & Development
# ...    ...       ...            ...        ...                     ...
# 1020  41.0        No  Travel_Rarely     1276.0                   Sales
# 1021  33.0        No     Non-Travel      750.0                   Sales
# 1023  33.0        No  Travel_Rarely      589.0  Research & Development
# 1027  29.0        No  Travel_Rarely     1378.0  Research & Development
# 1028  50.0        No  Travel_Rarely      264.0                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.to_excel("D:\BOARD INFINITY PROJECTS\Employee attribution\employee_attrition.xlsx")

# %%
plt.figure(figsize = (6,5))
sns.barplot(x = 'Department', y = 'Yes',hue = 'Gender', data = df)
plt.title('BusinessTravel wise Attrition')
plt.show()
